# %% [markdown]
# IMPORT IMPORTANT LIBRARIES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/avocado.csv.zip')

# %%
df.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# ...

# %% [markdown]
# DATA LOADING & PREPROCESSING

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    18249 non-null  int64
#  1   Date          18249 non-null  object
#  2   AveragePrice  18249 non-null  float64
#  3   Total Volume  18249 non-null  float64
#  4   4046          18249 non-null  float64
#  5   4225          18249 non-null  float64
#  6   4770          18249 non-null  float64
#  7   Total Bags    18249 non-null  float64
#  8   Small Bags    18249 non-null  float64
#  9   Large Bags    18249 non-null  float64
#  10  XLarge Bags   18249 non-null  float64
#  11  type          18249 non-null  object
#  12  year          18249 non-null  int64
#  13  region        18249 non-null  object
# dtypes: float64(9), int64(2), object(3)
# memory usage: 1.9+ MB

# %%
df.shape
# Out:
# (18249, 14)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0      0
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %% [markdown]
# DATA VISUALISATION

# %%
df['type'].value_counts()
# Out:
# type
# conventional    9126
# organic         9123
# Name: count, dtype: int64

# %%
df['type']=df['type'].map({'conventional':0,'organic':1})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    18249 non-null  int64
#  1   Date          18249 non-null  object
#  2   AveragePrice  18249 non-null  float64
#  3   Total Volume  18249 non-null  float64
#  4   4046          18249 non-null  float64
#  5   4225          18249 non-null  float64
#  6   4770          18249 non-null  float64
#  7   Total Bags    18249 non-null  float64
#  8   Small Bags    18249 non-null  float64
#  9   Large Bags    18249 non-null  float64
#  10  XLarge Bags   18249 non-null  float64
#  11  type          18249 non-null  int64
#  12  year          18249 non-null  int64
#  13  region        18249 non-null  object
# dtypes: float64(9), int64(3), object(2)
# memory usage: 1.9+ MB

# %%
geo=df['region'].value_counts()

# %%
sns.countplot(x='year',data=df,hue='type')
# Out:
# <Axes: xlabel='year', ylabel='count'>

# %%
df['year'].value_counts()
# Out:
# year
# 2017    5722
# 2016    5616
# 2015    5615
# 2018    1296
# Name: count, dtype: int64

# %%
sns.boxplot(y='AveragePrice',x='year',data=df)
# Out:
# <Axes: xlabel='year', ylabel='AveragePrice'>

# %%
df['Date']=df['Date'].apply(pd.to_datetime)

# %%
df['Date']
# Out:
# 0       2015-12-27
# 1       2015-12-20
# 2       2015-12-13
# 3       2015-12-06
# 4       2015-11-29
#            ...
# 18244   2018-02-04
# 18245   2018-01-28
# 18246   2018-01-21
# 18247   2018-01-14
# 18248   2018-01-07
# Name: Date, Length: 18249, dtype: datetime64[ns]

# %%
df['month']=df['Date'].apply(lambda x:x.month)

# %%
df
# Out:
#        Unnamed: 0       Date  AveragePrice  Total Volume     4046       4225  \
# 0               0 2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1 2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2 2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3 2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4 2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...        ...           ...           ...      ...        ...
# 18244           7 2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8 2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9 2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10 2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11 2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %%
dataset=df.copy()

# %%
dataset
# Out:
#        Unnamed: 0       Date  AveragePrice  Total Volume     4046       4225  \
# 0               0 2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1 2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2 2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3 2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4 2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...        ...           ...           ...      ...        ...
# 18244           7 2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8 2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9 2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10 2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11 2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %%
# dataset.date = dataset.date.apply(pd.to_datetime)
dataset['month']=dataset['Date'].apply(lambda x:x.month)
dataset.drop('Date',axis=1,inplace=True)
dataset['month'] = dataset['month'].map({1:'Jan',2:'Feb',3:'Mar',4:'Apr',5:'May',6:'Jun',7:'Jul',8:'Aug',9:'Sep',10:'Oct',11:'Nov',12:'Dec'})

# %%
dataset['month']
# Out:
# 0        Dec
# 1        Dec
# 2        Dec
# 3        Dec
# 4        Nov
#         ...
# 18244    Feb
# 18245    Jan
# 18246    Jan
# 18247    Jan
# 18248    Jan
# Name: month, Length: 18249, dtype: object

# %%
dataset['month']
# Out:
# 0        Dec
# 1        Dec
# 2        Dec
# 3        Dec
# 4        Nov
#         ...
# 18244    Feb
# 18245    Jan
# 18246    Jan
# 18247    Jan
# 18248    Jan
# Name: month, Length: 18249, dtype: object

# %%
sns.countplot(x='month',data=dataset,hue='type')
# Out:
# <Axes: xlabel='month', ylabel='count'>

# %%
dummies=pd.get_dummies(dataset[['year','region','month']],drop_first=True)

# %%
dummies.columns
# Out:
# Index(['year', 'region_Atlanta', 'region_BaltimoreWashington', 'region_Boise',
#        'region_Boston', 'region_BuffaloRochester', 'region_California',
#        'region_Charlotte', 'region_Chicago', 'region_CincinnatiDayton',
#        'region_Columbus', 'region_DallasFtWorth', 'region_Denver',
#        'region_Detroit', 'region_GrandRapids', 'region_GreatLakes',
#        'region_HarrisburgScranton', 'region_HartfordSpringfield',
#        'region_Houston', 'region_Indianapolis', 'region_Jacksonville',
#        'region_LasVegas', 'region_LosAngeles', 'region_Louisville',
#        'region_MiamiFtLauderdale', 'region_Midsouth', 'region_Nashville',
#        'region_NewOrleansMobile', 'region_NewYork', 'region_Northeast',
#        'region_NorthernNewEngland', 'region_Orlando', 'region_Philadelphia',
#        'region_PhoenixTucson', 'region_Pittsburgh', 'region_Plains',
#        'region_Portland', 'region_RaleighGreensboro', 'region_RichmondNorfolk',
# ...

# %%
dataset.columns
# Out:
# Index(['Unnamed: 0', 'AveragePrice', 'Total Volume', '4046', '4225', '4770',
#        'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type', 'year',
#        'region', 'month'],
#       dtype='object')

# %%
dummies
# Out:
#        year  region_Atlanta  region_BaltimoreWashington  region_Boise  \
# 0      2015           False                       False         False
# 1      2015           False                       False         False
# 2      2015           False                       False         False
# 3      2015           False                       False         False
# 4      2015           False                       False         False
# ...     ...             ...                         ...           ...
# 18244  2018           False                       False         False
# 18245  2018           False                       False         False
# 18246  2018           False                       False         False
# 18247  2018           False                       False         False
# 18248  2018           False                       False         False
#
#        region_Boston  region_BuffaloRochester  region_California  \
# ...

# %%
x = pd.concat([dataset[['Total Volume','4046','4225','4770','Total Bags','Small Bags','Large Bags','XLarge Bags','type']],dummies],axis=1)

# %%
if 'AveragePrice' in x.columns:
    print('present')
else:
    pass

# %%
y = dataset['AveragePrice']

# %% [markdown]
# MODEL EVALUATION & BUILDING

# %%
  from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=42)

# %%
x_train
# Out:
#        Total Volume        4046       4225      4770  Total Bags  Small Bags  \
# 8704     1316347.07   548774.22  292561.60   6066.33   468944.92   355573.55
# 5271       83933.43    24615.83   16234.66   2321.26    40761.68    40759.30
# 7654      267806.51    89083.09   79805.02   1830.85    97087.55    90560.26
# 2417     4295280.16  2713600.49  592279.23  97111.62   892288.82   621425.86
# 11906      13816.71     6430.36    4300.00      0.00     3086.35     2744.50
# ...             ...         ...        ...       ...         ...         ...
# 11284      12946.65     2398.15   10206.13      0.00      342.37      342.37
# 11964       1193.06       26.72     346.19      0.00      820.15      820.15
# 5390       83407.69      992.24   54950.48    769.07    26695.90    26695.90
# 860       277578.88    42766.16  140403.76   2028.31    92380.65    87952.58
# 15795       3551.43      568.01    1410.33      0.00     1573.09      959.37
#
# ...

# %%
col=dataset[['Total Volume','4046','4225','4770','Total Bags','Small Bags','Large Bags','XLarge Bags']]

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
s=scaler.fit(x_train[['Total Volume','4046','4225','4770','Total Bags','Small Bags','Large Bags','XLarge Bags']])

# %%
x_train
# Out:
#        Total Volume        4046       4225      4770  Total Bags  Small Bags  \
# 8704     1316347.07   548774.22  292561.60   6066.33   468944.92   355573.55
# 5271       83933.43    24615.83   16234.66   2321.26    40761.68    40759.30
# 7654      267806.51    89083.09   79805.02   1830.85    97087.55    90560.26
# 2417     4295280.16  2713600.49  592279.23  97111.62   892288.82   621425.86
# 11906      13816.71     6430.36    4300.00      0.00     3086.35     2744.50
# ...             ...         ...        ...       ...         ...         ...
# 11284      12946.65     2398.15   10206.13      0.00      342.37      342.37
# 11964       1193.06       26.72     346.19      0.00      820.15      820.15
# 5390       83407.69      992.24   54950.48    769.07    26695.90    26695.90
# 860       277578.88    42766.16  140403.76   2028.31    92380.65    87952.58
# 15795       3551.43      568.01    1410.33      0.00     1573.09      959.37
#
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)

# %%
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error

# %%
mae=mean_absolute_error(y_test,y_pred)
mse=mean_squared_error(y_test,y_pred)
r2=r2_score(y_test,y_pred)

# %%
mae
# Out:
# 0.06144492701063227

# %%
mse
# Out:
# 0.06144492701063227

# %%
r2
# Out:
# 0.619154618395263
